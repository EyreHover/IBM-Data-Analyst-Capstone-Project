# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Exploratory Data Analysis Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this module you get to work with the cleaned dataset from the previous module.
#
# In this assignment you will perform the task of exploratory data analysis.
# You will find out the distribution of data, presence of outliers and also determine the correlation between different columns in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify the distribution of data in the dataset.
#
# -   Identify outliers in the dataset.
#
# -   Remove outliers from the dataset.
#
# -   Identify correlation between features in the dataset.

# %% [markdown]
# * * *

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import the pandas module.

# %%
import pandas as pd

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# %% [markdown]
# ## Distribution

# %% [markdown]
# ### Determine how the data is distributed

# %% [markdown]
# The column `ConvertedComp` contains Salary converted to annual USD salaries using the exchange rate on 2019-02-01.
#
# This assumes 12 working months and 50 working weeks.

# %% [markdown]
# Plot the distribution curve for the column `ConvertedComp`.

# %%
import seaborn as sns
ax = sns.distplot(df['ConvertedComp'], color='green', kde = True, bins=25)

# %% [markdown]
# Plot the histogram for the column `ConvertedComp`.

# %%
import matplotlib.pyplot as plt

plt.hist(x=df["ConvertedComp"], color='red')
plt.xlabel('ConvertedComp')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# What is the median of the column `ConvertedComp`?

# %%
# your code goes here
df["ConvertedComp"].median()
# Out:
# 57745.0

# %%
df.head()
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
# 2          13  I am a developer by profession      Yes
# 3          16  I am a developer by profession      Yes
# 4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# ...

# %% [markdown]
# How many responders identified themselves only as a **Man**?

# %%
# your code goes here
df["Gender"].value_counts()
# Out:
# Man                                                            10480
# Woman                                                            731
# Non-binary, genderqueer, or gender non-conforming                 63
# Man;Non-binary, genderqueer, or gender non-conforming             26
# Woman;Non-binary, genderqueer, or gender non-conforming           14
# Woman;Man                                                          9
# Woman;Man;Non-binary, genderqueer, or gender non-conforming        2
# Name: Gender, dtype: int64

# %% [markdown]
# Find out the  median ConvertedComp of responders identified themselves only as a **Woman**?

# %%
# your code goes here
df[df["Gender"] == "Woman"]["ConvertedComp"].median()
# Out:
# 57708.0

# %% [markdown]
# Give the five number summary for the column `Age`?

# %% [markdown]
# **Double click here for hint**.
#
# <!--
# min,q1,median,q3,max of a column are its five number summary.
# -->

# %%
# your code goes here
df["Age"].describe()
# Out:
# count    11111.000000
# mean        30.778895
# std          7.393686
# min         16.000000
# 25%         25.000000
# 50%         29.000000
# 75%         35.000000
# max         99.000000
# Name: Age, dtype: float64

# %% [markdown]
# Plot a histogram of the column `Age`.

# %%
# your code goes here
plt.hist(x=df["Age"], color='yellow', bins=30)
plt.xlabel('Age')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df["Age"].median()
# Out:
# 29.0

# %% [markdown]
# ## Outliers

# %% [markdown]
# ### Finding outliers

# %% [markdown]
# Find out if outliers exist in the column `ConvertedComp` using a box plot?

# %%
# your code goes here
ax = sns.boxplot(y='ConvertedComp', data=df)

# %% [markdown]
# Find out the Inter Quartile Range for the column `ConvertedComp`.

# %%
# your code goes here
q1 = df["ConvertedComp"].quantile(0.25)
q3 = df["ConvertedComp"].quantile(0.75)
IQR = q3 - q1
IQR
# Out:
# 73132.0

# %% [markdown]
# Find out the upper and lower bounds.

# %%
# your code goes here
upper = q3 + 1.5 * IQR
print('Upper=', upper)
lower = q1 - 1.5 * IQR
print("Lower=", lower)
# Out:
# Upper= 209698.0
# Lower= -82830.0

# %% [markdown]
# Identify how many outliers are there in the `ConvertedComp` column.

# %%
((df["ConvertedComp"] < lower) | (df["ConvertedComp"] > upper)).sum()
# Out:
# 879

# %% [markdown]
# Create a new dataframe by removing the outliers from the `ConvertedComp` column.

# %%
df_without_outliers = df[(df['ConvertedComp'] > (q1 - 1.5 * IQR)) & (df['ConvertedComp'] < (q3 + 1.5 * IQR))]

# %%
df_without_outliers["ConvertedComp"].describe()
# Out:
# count      9703.000000
# mean      59883.208389
# std       43394.336755
# min           0.000000
# 25%       24060.000000
# 50%       52704.000000
# 75%       85574.500000
# max      209356.000000
# Name: ConvertedComp, dtype: float64

# %%
df_without_outliers.dtypes
# Out:
# Respondent       int64
# MainBranch      object
# Hobbyist        object
# OpenSourcer     object
# OpenSource      object
#                  ...
# Ethnicity       object
# Dependents      object
# SurveyLength    object
# SurveyEase      object
# Outlier           bool
# Length: 86, dtype: object

# %%
df_without_outliers["ConvertedComp"].median()
# Out:
# 52704.0

# %%
df_without_outliers["ConvertedComp"].mean()
# Out:
# 59883.20838915799

# %%
ax = sns.boxplot(y='Age', data=df)

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### Finding correlation

# %% [markdown]
# Find the correlation between `Age` and all other numerical columns.

# %%
# your code goes here
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

# %%
df_without_outliers['Age'].isnull().sum()
# Out:
# 210

# %%
df_without_outliers['Respondent'].isnull().sum()
# Out:
# 0

# %%
df_without_outliers['CodeRevHrs'].isnull().sum()
# Out:
# 2091

# %%
df_without_outliers['CompTotal'].isnull().sum()
# Out:
# 0

# %%
df_without_outliers['WorkWeekHrs'].isnull().sum()
# Out:
# 39

# %%
df_without_age_outliers = df_without_outliers[(df_without_outliers['Age'].isnull() == False)]  
df_without_age_outliers
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 0               4  I am a developer by profession       No
# 1               9  I am a developer by profession      Yes
# 2              13  I am a developer by profession      Yes
# 4              17  I am a developer by profession      Yes
# 5              19  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 11392       25134  I am a developer by profession      Yes
# 11393       25136  I am a developer by profession      Yes
# 11394       25137  I am a developer by profession      Yes
# 11395       25138  I am a developer by profession      Yes
# 11396       25141  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                             Once a month or more often
# 2      Less than once a month but more than once per ...
# ...

# %%
df_without_age_or_CodeRevHrs_outliers = df_without_age_outliers[(df_without_age_outliers['CodeRevHrs'].isnull() == False)]  
df_without_age_or_CodeRevHrs_outliers.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 1           9                     I am a developer by profession      Yes
# 2          13                     I am a developer by profession      Yes
# 4          17                     I am a developer by profession      Yes
# 5          19                     I am a developer by profession      Yes
# 6          20  I am not primarily a developer, but I write co...       No
#
#                                          OpenSourcer  \
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 4  Less than once a month but more than once per ...
# 5                                              Never
# 6                                              Never
#
#                                           OpenSource          Employment  \
# 1  The quality of OSS and closed source software ...  Employed full-time
# ...

# %%
df_without_age_or_CodeRevHrs_outliers['WorkWeekHrs'].isnull().sum()
# Out:
# 26

# %%
df_without_any_outliers = df_without_age_or_CodeRevHrs_outliers[(df_without_age_or_CodeRevHrs_outliers['WorkWeekHrs'].isnull() == False)]  
df_without_any_outliers.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 1           9                     I am a developer by profession      Yes
# 2          13                     I am a developer by profession      Yes
# 4          17                     I am a developer by profession      Yes
# 5          19                     I am a developer by profession      Yes
# 6          20  I am not primarily a developer, but I write co...       No
#
#                                          OpenSourcer  \
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 4  Less than once a month but more than once per ...
# 5                                              Never
# 6                                              Never
#
#                                           OpenSource          Employment  \
# 1  The quality of OSS and closed source software ...  Employed full-time
# ...

# %%
ax = sns.scatterplot(x='Age', y='Respondent', data=df_without_any_outliers)

# %%
ax = sns.scatterplot(x='Age', y='CodeRevHrs', data=df_without_any_outliers)

# %%
ax = sns.scatterplot(x='Age', y='CompTotal', data=df_without_any_outliers)

# %%
ax = sns.scatterplot(x='Age', y='WorkWeekHrs', data=df_without_any_outliers)

# %%
ax = sns.scatterplot(x='Age', y='ConvertedComp', data=df_without_any_outliers)

# %%
import sklearn
sklearn.metrics.r2_score(Y , Yhat)
# Out:
# 0.00017921024698164256

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
